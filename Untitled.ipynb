# %%
# %config Completer.use_jedi = False

# %%
import numpy
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from cartoplot import cartoplot
import numpy as np
import mask

# %%
my_mask = mask.get('mask')
lons = mask.get('lon')
lats = mask.get('lat')

# %%
plt.imshow(my_mask)

# %%
data = Dataset('/home/robbie/Dropbox/SM_Thickness/data/CDS_type/monmeans/361/2003_04_monthlymean.nc')
data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     title: Monthly sea ice type data regridded on 361x361 EASE grid
#     month: 04
#     year: 2003
#     dimensions(sizes): x(361), y(361)
#     variables(dimensions): int32 ice_type(x,y), float32 lon(x,y), float32 lat(x,y)
#     groups:

# %%
ice_type = np.array(data['ice_type'])

# %%
plt.imshow(ice_type)

# %%
cartoplot(lons,lats,ice_type,land=False)

# %%
beaufort_ice_type = np.ma.masked_where(my_mask==9,ice_type)

# %%
plt.imshow(beaufort_ice_type)

# %%
beaufort_ice_type = mask.select_region('Beaufort',ice_type)

# %%
plt.imshow(beaufort_ice_type)

# %%
cartoplot(lons,lats,beaufort_ice_type)
